# %%
import pandas as pd
import random

# %%
quarters = ["2017Q1", "2017Q2", "2017Q3", "2017Q4", "2018Q1", "2018Q2", "2018Q3","2018Q4","2019Q1", "2019Q2", "2019Q3", 
            "2019Q4", "2020Q1"]

df = pd.DataFrame()

for quarter in quarters:
    temp = pd.read_csv(f"Data\{quarter}.csv")
    temp = temp.sample(frac=.05, random_state = 43)
    df = df.append(temp)
    print(quarter)
# Out:
# 2017Q1
# 2017Q2
# 2017Q3
# 2017Q4
# 2018Q1
# 2018Q2
# 2018Q3
# 2018Q4
# 2019Q1
# 2019Q2
# 2019Q3
# 2019Q4
# 2020Q1

# %%
df.head()
# Out:
#             ITIN_ID  COUPONS  YEAR  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 251472  20171122129        2  2017              13930                1393004
# 273543  20171132792        4  2017              10529                1052904
# 923524  20171535720        3  2017              14107                1410702
# 57581    2017124577        1  2017              11278                1127803
# 817637  20171459971        2  2017              11057                1105703
#
#         ORIGIN_CITY_MARKET_ID  QUARTER ORIGIN ORIGIN_STATE_ABR  ORIGIN_WAC  \
# 251472                  30977        1    ORD               IL          41
# 273543                  30529        1    BDL               CT          11
# 923524                  30466        1    PHX               AZ          81
# 57581                   30852        1    DCA               VA          38
# 817637                  31057        1    CLT               NC          36
#
# ...

# %%
len(df)
# Out:
# 4960187

# %%
df["Qtr_Year"] = 'Q' + df['QUARTER'].map(str) + '-' + df['YEAR'].map(str)

# %%
quarters = ["2017Q1", "2017Q2", "2017Q3", "2017Q4", "2018Q1", "2018Q2", "2018Q3","2018Q4","2019Q1", "2019Q2", "2019Q3", 
            "2019Q4", "2020Q1"]

df2 = pd.DataFrame()

for quarter in quarters:
    temp = pd.read_csv(f"Data\{quarter}-FARE.csv")
    temp = temp.sample(frac=.1, random_state = 43)
    df2 = df2.append(temp)
    print(quarter)
# Out:
# 2017Q1
# 2017Q2
# 2017Q3
# 2017Q4
# 2018Q1
# 2018Q2
# 2018Q3
# 2018Q4
# 2019Q1
# 2019Q2
# 2019Q3
# 2019Q4
# 2020Q1

# %%
joinedDf = pd.merge(df, df2, on='ITIN_ID')

# %%
joinedDf.columns
# Out:
# Index(['ITIN_ID', 'COUPONS', 'YEAR', 'ORIGIN_AIRPORT_ID',
#        'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID', 'QUARTER', 'ORIGIN',
#        'ORIGIN_STATE_ABR', 'ORIGIN_WAC', 'DEST_AIRPORT_ID',
#        'DEST_AIRPORT_SEQ_ID', 'DEST_CITY_MARKET_ID', 'DEST', 'DEST_STATE_ABR',
#        'DEST_WAC', 'TICKET_CARRIER', 'OPERATING_CARRIER', 'REPORTING_CARRIER',
#        'PASSENGERS_x', 'DISTANCE', 'Unnamed: 21', 'Qtr_Year', 'PASSENGERS_y',
#        'ITIN_FARE', 'Unnamed: 3'],
#       dtype='object')

# %%
joinedDf.head()
# Out:
#        ITIN_ID  COUPONS  YEAR  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 0  20171122129        2  2017              13930                1393004
# 1  20171101856        4  2017              10397                1039705
# 2  20171101856        4  2017              11057                1105703
# 3   2017192037        2  2017              10140                1014003
# 4  20171345566        2  2017              14107                1410702
#
#    ORIGIN_CITY_MARKET_ID  QUARTER ORIGIN ORIGIN_STATE_ABR  ORIGIN_WAC  ...  \
# 0                  30977        1    ORD               IL          41  ...
# 1                  30397        1    ATL               GA          34  ...
# 2                  31057        1    CLT               NC          36  ...
# 3                  30140        1    ABQ               NM          86  ...
# 4                  30466        1    PHX               AZ          81  ...
#
#    TICKET_CARRIER  OPERATING_CARRIER  REPORTING_CARRIER PASSENGERS_x DISTANCE  \
# ...

# %%
joinedDf = joinedDf.rename(columns = {
    'ITIN_ID': "Itinerary_ID",
    'COUPONS': 'Number_Coupons',
    'YEAR': 'Year',
    'ORIGIN_AIRPORT_ID': 'Origin_Airport_ID',
    'ORIGIN_AIRPORT_SEQ_ID': 'Origin_Airport_Seq_ID',
    'ORIGIN_CITY_MARKET_ID': 'Origin_City_Market_ID',
    'QUARTER': 'Quarter',
    'ORIGIN': 'Origin',
    'ORIGIN_STATE_ABR': 'Origin_State',
    'ORIGIN_WAC': 'Origin_WAC',
    'DEST_AIRPORT_ID': 'Dest_Airport_ID',
    'DEST_AIRPORT_SEQ_ID': 'Dest_Airport_Seq_ID',
    'DEST_CITY_MARKET_ID': 'Dest_City_Market_ID',
    'DEST': "Destination",
    'DEST_STATE_ABR': "Dest_State",
    'DEST_WAC': 'Dest_WAC',
    'TICKET_CARRIER': 'Ticket_Carrier',
    'OPERATING_CARRIER': 'Operating_Carrier',
    'REPORTING_CARRIER': 'Reporting_Carrier',
    'PASSENGERS_y': 'Number_Passengers',
    'ITIN_FARE': 'Fare',
    'DISTANCE': 'Flight_Distance'})
joinedDf.head()
# Out:
#    Itinerary_ID  Number_Coupons  Year  Origin_Airport_ID  \
# 0   20171122129               2  2017              13930
# 1   20171101856               4  2017              10397
# 2   20171101856               4  2017              11057
# 3    2017192037               2  2017              10140
# 4   20171345566               2  2017              14107
#
#    Origin_Airport_Seq_ID  Origin_City_Market_ID  Quarter Origin Origin_State  \
# 0                1393004                  30977        1    ORD           IL
# 1                1039705                  30397        1    ATL           GA
# 2                1105703                  31057        1    CLT           NC
# 3                1014003                  30140        1    ABQ           NM
# 4                1410702                  30466        1    PHX           AZ
#
#    Origin_WAC  ...  Ticket_Carrier  Operating_Carrier  Reporting_Carrier  \
# 0          41  ...              AA                 AA                 AA
# ...

# %%
joinedDf.columns
# Out:
# Index(['Itinerary_ID', 'Number_Coupons', 'Year', 'Origin_Airport_ID',
#        'Origin_Airport_Seq_ID', 'Origin_City_Market_ID', 'Quarter', 'Origin',
#        'Origin_State', 'Origin_WAC', 'Dest_Airport_ID', 'Dest_Airport_Seq_ID',
#        'Dest_City_Market_ID', 'Destination', 'Dest_State', 'Dest_WAC',
#        'Ticket_Carrier', 'Operating_Carrier', 'Reporting_Carrier',
#        'PASSENGERS_x', 'Flight_Distance', 'Unnamed: 21', 'Qtr_Year',
#        'Number_Passengers', 'Fare', 'Unnamed: 3'],
#       dtype='object')

# %%
joinedDf = joinedDf[['Itinerary_ID',
         'Qtr_Year',
         'Year',
         'Quarter',
         'Number_Coupons',
         'Origin_Airport_ID',
         'Origin_Airport_Seq_ID',
         'Origin_City_Market_ID',
         'Origin',
         'Origin_State',
         'Origin_WAC',
         'Dest_Airport_ID',
         'Dest_Airport_Seq_ID',
         'Dest_City_Market_ID',
         'Destination',
         'Dest_State',
         'Dest_WAC',
         'Flight_Distance',
         'Fare',
         'Ticket_Carrier',
         'Operating_Carrier',
         'Reporting_Carrier',
         'Number_Passengers']]
joinedDf.head()
# Out:
#    Itinerary_ID Qtr_Year  Year  Quarter  Number_Coupons  Origin_Airport_ID  \
# 0   20171122129  Q1-2017  2017        1               2              13930
# 1   20171101856  Q1-2017  2017        1               4              10397
# 2   20171101856  Q1-2017  2017        1               4              11057
# 3    2017192037  Q1-2017  2017        1               2              10140
# 4   20171345566  Q1-2017  2017        1               2              14107
#
#    Origin_Airport_Seq_ID  Origin_City_Market_ID Origin Origin_State  ...  \
# 0                1393004                  30977    ORD           IL  ...
# 1                1039705                  30397    ATL           GA  ...
# 2                1105703                  31057    CLT           NC  ...
# 3                1014003                  30140    ABQ           NM  ...
# 4                1410702                  30466    PHX           AZ  ...
#
# ...

# %%
airportsDf = pd.read_csv('Data/airportData.csv')
airportsDf.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
airportsDf = airportsDf.rename(columns = {
    'IATA_CODE': 'Origin',
    'AIRPORT': 'Origin_Airport',
    'CITY': 'Origin_City',
    'STATE': 'State',
    'COUNTRY': 'Country',
    'LATITUDE': 'Origin_Lat',
    'LONGITUDE': 'Origin_Long'
})
airportsDf.head()
# Out:
#   Origin                       Origin_Airport  Origin_City State Country  \
# 0    ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1    ABI             Abilene Regional Airport      Abilene    TX     USA
# 2    ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3    ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4    ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    Origin_Lat  Origin_Long
# 0    40.65236    -75.44040
# 1    32.41132    -99.68190
# 2    35.04022   -106.60919
# 3    45.44906    -98.42183
# 4    31.53552    -84.19447

# %%
originsDf = airportsDf[[
    'Origin',
    'Origin_Airport',
    'Origin_City',
    'Origin_Lat',
    'Origin_Long'
]]

# %%
totalDf = pd.merge(joinedDf, originsDf, on='Origin')

# %%
destinationsDf = airportsDf.rename(columns = {
    'Origin': 'Destination',
    'Origin_Airport': 'Destination_Airport',
    'Origin_City': 'Destination_City',
    'Origin_Lat': 'Destination_Lat',
    'Origin_Long': 'Destination_Long'
})
destinationsDf.head()
# Out:
#   Destination                  Destination_Airport Destination_City State  \
# 0         ABE  Lehigh Valley International Airport        Allentown    PA
# 1         ABI             Abilene Regional Airport          Abilene    TX
# 2         ABQ    Albuquerque International Sunport      Albuquerque    NM
# 3         ABR            Aberdeen Regional Airport         Aberdeen    SD
# 4         ABY   Southwest Georgia Regional Airport           Albany    GA
#
#   Country  Destination_Lat  Destination_Long
# 0     USA         40.65236         -75.44040
# 1     USA         32.41132         -99.68190
# 2     USA         35.04022        -106.60919
# 3     USA         45.44906         -98.42183
# 4     USA         31.53552         -84.19447

# %%
finalDf = pd.merge(totalDf, destinationsDf, on='Destination')

# %%
finalDf
# Out:
#         Itinerary_ID Qtr_Year  Year  Quarter  Number_Coupons  \
# 0        20171122129  Q1-2017  2017        1               2
# 1        20171122086  Q1-2017  2017        1               4
# 2        20171122803  Q1-2017  2017        1               4
# 3        20172143270  Q2-2017  2017        2               3
# 4        20172147951  Q2-2017  2017        2               2
# ...              ...      ...   ...      ...             ...
# 408557  201943658354  Q4-2019  2019        4               2
# 408558  201943658307  Q4-2019  2019        4               4
# 408559  201742488253  Q4-2017  2017        4               3
# 408560  201741118576  Q4-2017  2017        4               5
# 408561  201931387569  Q3-2019  2019        3               6
#
#         Origin_Airport_ID  Origin_Airport_Seq_ID  Origin_City_Market_ID  \
# 0                   13930                1393004                  30977
# 1                   13930                1393004                  30977
# ...

# %%
cleanDf = finalDf[~(finalDf['Fare'] > 2000)]

# %%
cleanDf = cleanDf[~(cleanDf['Fare'] < 50)]
cleanDf.head()
# Out:
#    Itinerary_ID Qtr_Year  Year  Quarter  Number_Coupons  Origin_Airport_ID  \
# 0   20171122129  Q1-2017  2017        1               2              13930
# 1   20171122086  Q1-2017  2017        1               4              13930
# 2   20171122803  Q1-2017  2017        1               4              13930
# 3   20172143270  Q2-2017  2017        2               3              13930
# 4   20172147951  Q2-2017  2017        2               2              13930
#
#    Origin_Airport_Seq_ID  Origin_City_Market_ID Origin Origin_State  ...  \
# 0                1393004                  30977    ORD           IL  ...
# 1                1393004                  30977    ORD           IL  ...
# 2                1393004                  30977    ORD           IL  ...
# 3                1393004                  30977    ORD           IL  ...
# 4                1393004                  30977    ORD           IL  ...
#
# ...

# %%
cleanDf = cleanDf[~(cleanDf['Number_Passengers'] > 100)]
cleanDf.head()
# Out:
#    Itinerary_ID Qtr_Year  Year  Quarter  Number_Coupons  Origin_Airport_ID  \
# 0   20171122129  Q1-2017  2017        1               2              13930
# 1   20171122086  Q1-2017  2017        1               4              13930
# 2   20171122803  Q1-2017  2017        1               4              13930
# 3   20172143270  Q2-2017  2017        2               3              13930
# 4   20172147951  Q2-2017  2017        2               2              13930
#
#    Origin_Airport_Seq_ID  Origin_City_Market_ID Origin Origin_State  ...  \
# 0                1393004                  30977    ORD           IL  ...
# 1                1393004                  30977    ORD           IL  ...
# 2                1393004                  30977    ORD           IL  ...
# 3                1393004                  30977    ORD           IL  ...
# 4                1393004                  30977    ORD           IL  ...
#
# ...

# %%
cleanDf.to_csv("flightData.csv", index=False)

# %%
machineLearningDf = pd.read_csv('Data/2020Q1.csv').sample(frac=.25, random_state = 43)
machineLearningDf.head()
# Out:
#             ITIN_ID  COUPONS  YEAR  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 251472  20201115635        4  2020              10361                1036105
# 273543  20201127472        4  2020              10140                1014005
# 923524  20201529179        4  2020              10408                1040805
# 57581    2020123110        4  2020              11697                1169706
# 817637  20201450927        2  2020              12889                1288903
#
#         ORIGIN_CITY_MARKET_ID  QUARTER ORIGIN ORIGIN_STATE_ABR  ORIGIN_WAC  \
# 251472                  30361        1    ART               NY          22
# 273543                  30140        1    ABQ               NM          86
# 923524                  30408        1    ATW               WI          45
# 57581                   32467        1    FLL               FL          33
# 817637                  32211        1    LAS               NV          85
#
# ...

# %%
machineLearningDf2 = pd.read_csv('Data/2020Q1-Fare.csv').sample(frac=.25, random_state = 43)
machineLearningDf2.head()
# Out:
#              ITIN_ID  PASSENGERS  ITIN_FARE
# 251472  2.020134e+10           1        879
# 273543  2.020138e+10           1        470
# 923524  2.020110e+11           1        820
# 57581   2.020166e+09           1        188
# 817637  2.020110e+11           4        141

# %%
mlDf = pd.merge(machineLearningDf, machineLearningDf2, on='ITIN_ID')

# %%
mlDf = mlDf.rename(columns = {
    'ITIN_ID': "Itinerary_ID",
    'COUPONS': 'Number_Coupons',
    'YEAR': 'Year',
    'ORIGIN_AIRPORT_ID': 'Origin_Airport_ID',
    'ORIGIN_AIRPORT_SEQ_ID': 'Origin_Airport_Seq_ID',
    'ORIGIN_CITY_MARKET_ID': 'Origin_City_Market_ID',
    'QUARTER': 'Quarter',
    'ORIGIN': 'Origin',
    'ORIGIN_STATE_ABR': 'Origin_State',
    'ORIGIN_WAC': 'Origin_WAC',
    'DEST_AIRPORT_ID': 'Dest_Airport_ID',
    'DEST_AIRPORT_SEQ_ID': 'Dest_Airport_Seq_ID',
    'DEST_CITY_MARKET_ID': 'Dest_City_Market_ID',
    'DEST': "Destination",
    'DEST_STATE_ABR': "Dest_State",
    'DEST_WAC': 'Dest_WAC',
    'TICKET_CARRIER': 'Ticket_Carrier',
    'OPERATING_CARRIER': 'Operating_Carrier',
    'REPORTING_CARRIER': 'Reporting_Carrier',
    'PASSENGERS_y': 'Number_Passengers',
    'ITIN_FARE': 'Fare',
    'DISTANCE': 'Flight_Distance'})
mlDf.head()
# Out:
#    Itinerary_ID  Number_Coupons  Year  Origin_Airport_ID  \
# 0   20201127472               4  2020              10140
# 1    2020190570               4  2020              14027
# 2    2020190570               4  2020              10397
# 3    2020190570               4  2020              14814
# 4   20201349658               1  2020              11618
#
#    Origin_Airport_Seq_ID  Origin_City_Market_ID  Quarter Origin Origin_State  \
# 0                1014005                  30140        1    ABQ           NM
# 1                1402702                  34027        1    PBI           FL
# 2                1039707                  30397        1    ATL           GA
# 3                1481402                  30476        1    SHV           LA
# 4                1161802                  31703        1    EWR           NJ
#
#    Origin_WAC  ...  Destination  Dest_State  Dest_WAC Ticket_Carrier  \
# 0          86  ...          DFW          TX        74             AA
# ...

# %%
mlDf = mlDf[['Itinerary_ID',
         'Year',
         'Quarter',
         'Number_Coupons',
         'Origin_Airport_ID',
         'Origin_Airport_Seq_ID',
         'Origin_City_Market_ID',
         'Origin',
         'Origin_State',
         'Origin_WAC',
         'Dest_Airport_ID',
         'Dest_Airport_Seq_ID',
         'Dest_City_Market_ID',
         'Destination',
         'Dest_State',
         'Dest_WAC',
         'Flight_Distance',
         'Fare',
         'Ticket_Carrier',
         'Operating_Carrier',
         'Reporting_Carrier',
         'Number_Passengers']]
mlDf.head()
# Out:
#    Itinerary_ID  Year  Quarter  Number_Coupons  Origin_Airport_ID  \
# 0   20201127472  2020        1               4              10140
# 1    2020190570  2020        1               4              14027
# 2    2020190570  2020        1               4              10397
# 3    2020190570  2020        1               4              14814
# 4   20201349658  2020        1               1              11618
#
#    Origin_Airport_Seq_ID  Origin_City_Market_ID Origin Origin_State  \
# 0                1014005                  30140    ABQ           NM
# 1                1402702                  34027    PBI           FL
# 2                1039707                  30397    ATL           GA
# 3                1481402                  30476    SHV           LA
# 4                1161802                  31703    EWR           NJ
#
#    Origin_WAC  ...  Dest_City_Market_ID  Destination  Dest_State Dest_WAC  \
# 0          86  ...                30194          DFW          TX       74
# ...

# %%
mlDf = pd.merge(mlDf, originsDf, on='Origin')

# %%
mlDf = pd.merge(mlDf, destinationsDf, on='Destination')

# %%
cleanMlDf = mlDf[~(mlDf['Number_Passengers'] > 100)]
cleanMlDf.head()
# Out:
#    Itinerary_ID  Year  Quarter  Number_Coupons  Origin_Airport_ID  \
# 0   20201127472  2020        1               4              10140
# 1   20201106150  2020        1               5              10140
# 2   20201106311  2020        1               4              10140
# 3   20201105676  2020        1               2              10140
# 4   20201215946  2020        1               4              10140
#
#    Origin_Airport_Seq_ID  Origin_City_Market_ID Origin Origin_State  \
# 0                1014005                  30140    ABQ           NM
# 1                1014005                  30140    ABQ           NM
# 2                1014005                  30140    ABQ           NM
# 3                1014005                  30140    ABQ           NM
# 4                1014005                  30140    ABQ           NM
#
#    Origin_WAC  ...                     Origin_Airport  Origin_City  \
# 0          86  ...  Albuquerque International Sunport  Albuquerque
# ...

# %%
cleanMlDf = mlDf[~(mlDf['Fare'] > 2000)]
cleanMlDf.head()
# Out:
#    Itinerary_ID  Year  Quarter  Number_Coupons  Origin_Airport_ID  \
# 0   20201127472  2020        1               4              10140
# 1   20201106150  2020        1               5              10140
# 2   20201106311  2020        1               4              10140
# 3   20201105676  2020        1               2              10140
# 4   20201215946  2020        1               4              10140
#
#    Origin_Airport_Seq_ID  Origin_City_Market_ID Origin Origin_State  \
# 0                1014005                  30140    ABQ           NM
# 1                1014005                  30140    ABQ           NM
# 2                1014005                  30140    ABQ           NM
# 3                1014005                  30140    ABQ           NM
# 4                1014005                  30140    ABQ           NM
#
#    Origin_WAC  ...                     Origin_Airport  Origin_City  \
# 0          86  ...  Albuquerque International Sunport  Albuquerque
# ...

# %%
cleanMlDf = mlDf[~(mlDf['Fare'] < 50)]
cleanMlDf.head()
# Out:
#    Itinerary_ID  Year  Quarter  Number_Coupons  Origin_Airport_ID  \
# 1   20201106150  2020        1               5              10140
# 2   20201106311  2020        1               4              10140
# 4   20201215946  2020        1               4              10140
# 5   20201107689  2020        1               4              10140
# 6   20201105846  2020        1               2              10140
#
#    Origin_Airport_Seq_ID  Origin_City_Market_ID Origin Origin_State  \
# 1                1014005                  30140    ABQ           NM
# 2                1014005                  30140    ABQ           NM
# 4                1014005                  30140    ABQ           NM
# 5                1014005                  30140    ABQ           NM
# 6                1014005                  30140    ABQ           NM
#
#    Origin_WAC  ...                     Origin_Airport  Origin_City  \
# 1          86  ...  Albuquerque International Sunport  Albuquerque
# ...

# %%
mlDf.to_csv("machineLearningData.csv", index=False)
